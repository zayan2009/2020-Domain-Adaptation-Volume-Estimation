# %% [markdown]
# # Libs

# %%
import os
import time
import glob
import json
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import tensorflow.keras.backend as K
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, LeakyReLU, BatchNormalization
from tensorflow.keras.layers import Dense, Reshape, Activation, Dropout, Flatten
from tensorflow.keras.layers import Embedding, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import he_normal, constant
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical, normalize

from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error as mae
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import TruncatedSVD
from sklearn.neighbors import NearestNeighbors, KNeighborsRegressor

import lightgbm as lgb

# %% [markdown]
# # Load Data

# %%
avi_train_seg = np.load('../Data/avi_train_seg.npy')
trj_train_seg = np.load('../Data/trj_train_seg.npy')
lane_functions = np.load('../Data/lane_functions.npy')

# %%
num_lanes = lane_functions.sum(axis=1)
lane_functions = pd.DataFrame(lane_functions,columns=['through','left','right',
                                                      'thr_left','thr_right','u_turn'])
lane_functions['linkIdx'] = np.arange(1,25)
lane_functions['num_lanes'] = num_lanes

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(17, 15))
plt.subplot(221)
plt.scatter(trj_train_seg[:, :36, 10].reshape(-1),
            avi_train_seg[:, :36, 10].reshape(-1),
            s=20, marker='*', c='k')
plt.xlim([-0.2,18])
plt.ylim([-0.2,260])

plt.subplot(222)
plt.scatter(trj_train_seg[:, 36:72, 10].reshape(-1),
            avi_train_seg[:, 36:72, 10].reshape(-1),
            s=20, marker='+', c='g')
plt.xlim([-0.2,18])
plt.ylim([-0.2,260])

plt.subplot(223)
plt.scatter(trj_train_seg[:, 72:108, 10].reshape(-1),
            avi_train_seg[:, 72:108, 10].reshape(-1),
            s=20, marker='^', c='r')
plt.xlim([-0.2,18])
plt.ylim([-0.2,260])

plt.subplot(224)
plt.scatter(trj_train_seg[:, 108:144, 10].reshape(-1),
            avi_train_seg[:, 108:144, 10].reshape(-1),
            s=20, marker='o', c='b')
plt.xlim([-0.2,18])
plt.ylim([-0.2,260])
# Out:
# (-0.2, 260)

# %%
plt.figure(figsize=(20,12))
for i in range(6):
    plt.subplot(2,3,int(i+1))
    sns.kdeplot(trj_train_seg[:, 24 * i:24 * (i + 1), 1].reshape(-1),
                avi_train_seg[:, 24 * i:24 * (i + 1), 1].reshape(-1),
                cut=1,shade=True,vertical=True,cmap='viridis')

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Sample Preparation

# %%
def get_sample(trj_train_seg):
    data = pd.DataFrame(columns=['linkIdx','datetime','volume'])
    for approach in range(24):
        table = pd.DataFrame(np.zeros((30 * 144,3)),columns=['linkIdx','datetime','volume'])
        table.iloc[:,0] = approach + 1
        for day in range(30):
            if day < 9:
                datetime = [pd.to_datetime('2018010' + str(day + 1)) + pd.Timedelta(i * 10,unit='m') for i in range(144)]
            else:
                datetime = [pd.to_datetime('201801' + str(day + 1)) + pd.Timedelta(i * 10,unit='m') for i in range(144)]
            table.iloc[144 * day:144 * (day + 1),2] = trj_train_seg[day,:,approach]
            table.iloc[144 * day:144 * (day + 1),1] = datetime
        data = pd.concat((data,table))
    data['linkIdx'] = data['linkIdx'].astype('int')
    data['datetime'] = pd.to_datetime(data['datetime'])
    data['volume'] = data['volume'].astype('float')
    return data

# %%
X, Y = get_sample(trj_train_seg), get_sample(avi_train_seg)
print("[Basic Stats] num. of samples: {:d}".format(X.shape[0]))
# Out:
# [Basic Stats] num. of samples: 103680

# %% [markdown]
# ## Feature Engineering

# %%
# =============================
# Feature Engineering
# =============================

X = pd.merge(X,lane_functions)
X['hour'] = X['datetime'].map(lambda x:x.hour)
X['weekday'] = X['datetime'].map(lambda x:x.weekday())

def holiday(x):
    if x.month == 1 and x.day == 1:
        return 1
    else:
        return 0

def peak(x):
    if 7 < x.hour < 9:
        return 1
    elif 11 < x.hour < 13:
        return 2
    elif 17 < x.hour < 19:
        return 3
    else:
        return 0

def itv_cnt(x, itv_length=600):
    return (x.hour * 3600 + x.minute * 60) // itv_length

X['interval'] = X['datetime'].map(lambda x:itv_cnt(x))
X['holiday'] = X['datetime'].map(lambda x:holiday(x))
X['peak'] = X['datetime'].map(lambda x:peak(x))
X['linkIdx'] = X['linkIdx'].astype(int)

print("[Basic Stats] dim. of features: {:d}".format(X.shape[1]))
# Out:
# [Basic Stats] dim. of features: 15

# %%
def merge_volume_features(X, feature_cols, aggfuncs=['mean', 'median', 'std']):
    
    for feature in feature_cols:
        for fn in aggfuncs:
            df = X.pivot_table(index='linkIdx',
                               columns=feature,
                               values='volume',
                               aggfunc=fn).reset_index()
            df.columns = ['linkIdx'] + list(df.columns[1:])
            df = df.melt(id_vars=['linkIdx'],
                         value_vars=list(df.columns[1:]),
                         var_name=feature,
                         value_name=feature + '_' + fn + '_volume')
            df[feature] = pd.to_numeric(df[feature])
            X = pd.merge(X, df, on=['linkIdx',feature])
    return X

# %%
feature_cols = ['through', 'left', 'right', 'thr_left',
                'thr_right', 'u_turn', 'num_lanes', 'hour',
                'weekday', 'interval', 'holiday', 'peak']
X = merge_volume_features(X, feature_cols)

# %% [markdown]
# ## Evaluation Metric

# %%
def dataset_split(X, Y, split_mode):
    if split_mode is 'random':
        X_train, X_test, y_train, y_test = train_test_split(X.drop(['datetime','linkIdx'], axis=1),
                                                            Y['volume'],
                                                            test_size=0.2, random_state=2020)
    elif split_mode is 'transfer':
        train_idx = X[X['linkIdx'].isin([1,2,3,4,5,6,7,8,24,23,22,21,20,19,18,17,15,16])].index
        test_idx = X[X['linkIdx'].isin([9,10,11,12,13,14])].index
        X_train, X_test = X.drop(['linkIdx', 'datetime'], axis=1).iloc[train_idx, :], X.drop(
            ['linkIdx', 'datetime'], axis=1).iloc[test_idx, :]
        y_train, y_test = Y['volume'].iloc[train_idx], Y['volume'].iloc[test_idx]
    
    return X_train, X_test, y_train, y_test

# %%
split_mode = 'transfer'
X_train, X_test, y_train, y_test = dataset_split(X, Y, split_mode)

# %%
def mae(y_pred, y_test):
    return np.sum(np.abs(y_pred - y_test) * y_test) / np.sum(y_test)

def mape(y_pred, y_test):
    return np.sum(np.abs(y_pred - y_test)) / np.sum(y_test)

def mspe(y_pred, y_test):
    return np.sum(np.square(y_pred - y_test)) / np.sum(np.square(y_test))

# %% [markdown]
# # Model

# %% [markdown]
# ## Linear Regression

# %%
lr = LinearRegression()

lr = lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print("[LinearRegression] score: {:.3f} | mae: {:.2f} | mape: {:.2f}% | mspe: {:.2f}%".format(
    lr.score(X_train, y_train), mae(y_pred, y_test),
    100 * mape(y_pred, y_test), 100 * mspe(y_pred, y_test)))
# Out:
# [LinearRegression] score: 0.619 | mae: 38.57 | mape: 35.78% | mspe: 14.10%

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestRegressor(n_estimators=500,n_jobs=-1)

rf = rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
print("[RandomForest] score: {:.3f} | mae: {:.2f} | mape: {:.2f}% | mspe: {:.2f}%".format(
    rf.score(X_train,y_train),mae(y_pred, y_test),
    100 * mape(y_pred,y_test), 100 * mspe(y_pred, y_test)))
# Out:
# [RandomForest] score: 0.656 | mae: 58.26 | mape: 51.41% | mspe: 27.35%

# %% [markdown]
# ## LightGBM

# %%
train_data = lgb.Dataset(X_train, y_train, categorical_feature=['hour', 'weekday',
                                                                'holiday', 'peak',
                                                                'interval'])
test_data = lgb.Dataset(X_test, y_test, reference=train_data)

params = {
    'objective':'regression',
    'boosting':'dart',
    'num_rounds':10000,
    'learning_rate':0.01,
    'max_depth':8,
    'num_leaves':100,
    'bagging_fraction':0.8,
    'bagging_freq':50,
    'verbose':2
}

# %%
gbm = lgb.train(params, train_data)
y_pred = gbm.predict(X_test)
print("[LightGBM] mae: {:.2f} | mape: {:.2f}% | mspe: {:.2f}%".format(
    mae(y_pred, y_test),
    100 * mape(y_pred,y_test), 100 * mspe(y_pred, y_test)))
# Out:
# [LightGBM] mae: 31.11 | mape: 20.39% | mspe: 5.94%

# %%
plt.figure(figsize=(8,7))
plt.scatter(y_pred,y_test,c='',marker='^',edgecolors='k')
plt.plot(np.arange(420),np.arange(420),'r:')
plt.xlim([0,420])
plt.ylim([0,420])
# Out:
# (0, 420)

# %%
lgb.plot_importance(gbm,grid=False, height=0.5,max_num_features=20,figsize=(8,7))

# %% [markdown]
# ## MLP

# %%
def dataset_split(X, Y, split_mode):
    if split_mode is 'random':
        X_train, X_test, y_train, y_test = train_test_split(X.drop(['datetime','linkIdx'], axis=1),
                                                            Y['volume'],
                                                            test_size=0.2, random_state=2020)
    elif split_mode is 'transfer':
        train_idx = X[X['linkIdx'].isin([1,2,3,4,5,6,7,8,24,23,22,21,20,19,18,17,15,16])].index
        test_idx = X[X['linkIdx'].isin([9,10,11,12,13,14])].index
        X_train, X_test = X.drop(['linkIdx', 'datetime'], axis=1).iloc[train_idx, :], X.drop(
            ['linkIdx', 'datetime'], axis=1).iloc[test_idx, :]
        y_train, y_test = Y['volume'].iloc[train_idx], Y['volume'].iloc[test_idx]
    
    return X_train, X_test, y_train, y_test

# %%
split_mode = 'transfer'
X_train, X_test, y_train, y_test = dataset_split(X, Y, split_mode)
print("[Stats] Num. of features: {:d}".format(X_train.shape[1]))
# Out:
# [Stats] Num. of features: 49

# %%
def mae(y_pred, y_test):
    return np.sum(y_test * np.abs(y_pred - y_test)) / np.sum(y_test)

def mape(y_pred, y_test):
    return np.sum((np.abs(y_pred - y_test)) / np.sum(y_test))

def mspe(y_pred, y_test):
    return np.sum(np.square(y_pred - y_test)) / np.sum(np.square(y_test))

# %%
def one_hot_encoding(X, categorical_features):
    one_hot_enc = OneHotEncoder()
    for feat in categorical_features:
        encoded_matrix = one_hot_enc.fit_transform(X[feat].values.reshape(-1,1)).toarray()
        num_class = encoded_matrix.shape[1]
        one_hot_features = pd.DataFrame()
        for class_ in range(num_class):
            one_hot_features[feat + '_' + str(class_)] = encoded_matrix[:,class_]
        X = pd.concat((X, one_hot_features),axis=1)
    return X

# %%
categorical_features = ['hour', 'weekday', 'holiday', 'peak', 'interval']
numeric_features = list(set(X.columns) - set(categorical_features) - {'linkIdx','datetime'})
X_nn = one_hot_encoding(X, categorical_features)

split_mode = 'transfer'
X_train, X_test, y_train, y_test = dataset_split(X_nn, Y, split_mode)

# %%
def build_mlp(input_shape, drop_rate, name):
    x_in = Input(shape=(input_shape,),name='input')
    
    def build_dense(h, units, drop=True, norm=True):
        h = Dense(units=units,use_bias=True,activation=None,
                  kernel_initializer=he_normal(),
                  bias_initializer=constant(0.1),
                  kernel_regularizer=l2())(h)
        if norm:
            h = BatchNormalization()(h)
        h = LeakyReLU(0.1)(h)
        if drop:
            h = Dropout(rate=drop_rate)(h)
        return h
    
    h = build_dense(x_in, 256)
    h = build_dense(h, 128)
    h = build_dense(h, 64, drop=False)
    h = build_dense(h, 32, drop=False, norm=False)
    h = build_dense(h, 1, drop=False, norm=False)
    
    model = Model(inputs=x_in, outputs=h, name=name)
    
    return model

# %%
model = build_mlp(X_train.shape[1],drop_rate=0.3, name='mlp')
model.compile(loss='mse',optimizer=Adam(1e-3), metrics=['mae'])
model.summary()
# Out:
# Model: "mlp"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 230)]             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               59136
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 33
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 1)                 0
# =================================================================
# Total params: 104,193
# Trainable params: 103,297
# Non-trainable params: 896
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train,
                 epochs=100, batch_size=512,
                 validation_data=[X_test,y_test],
                 shuffle=True, verbose=1)
# Out:
# Train on 77760 samples, validate on 25920 samples
# Epoch 1/100
# 77760/77760 [==============================] - 2s 26us/sample - loss: 8244.5657 - mean_absolute_error: 68.9408 - val_loss: 9202.3244 - val_mean_absolute_error: 79.8433
# Epoch 2/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 2097.8932 - mean_absolute_error: 32.7972 - val_loss: 8644.0073 - val_mean_absolute_error: 77.0211
# Epoch 3/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 1393.5932 - mean_absolute_error: 26.1407 - val_loss: 2090.1961 - val_mean_absolute_error: 33.8527
# Epoch 4/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 1122.3357 - mean_absolute_error: 23.0537 - val_loss: 1752.4143 - val_mean_absolute_error: 30.1807
# Epoch 5/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 989.0590 - mean_absolute_error: 21.4065 - val_loss: 1711.7676 - val_mean_absolute_error: 29.0444
# Epoch 6/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 903.1508 - mean_absolute_error: 20.3106 - val_loss: 1667.8160 - val_mean_absolute_error: 28.0291
# Epoch 7/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 848.0183 - mean_absolute_error: 19.6012 - val_loss: 1067.6357 - val_mean_absolute_error: 22.3379
# Epoch 8/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 819.0057 - mean_absolute_error: 19.2214 - val_loss: 1488.8715 - val_mean_absolute_error: 26.6375
# Epoch 9/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 788.1036 - mean_absolute_error: 18.8096 - val_loss: 1292.8922 - val_mean_absolute_error: 24.5493
# Epoch 10/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 766.3838 - mean_absolute_error: 18.4760 - val_loss: 1221.8084 - val_mean_absolute_error: 24.0132
# Epoch 11/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 740.2927 - mean_absolute_error: 18.1155 - val_loss: 1089.6676 - val_mean_absolute_error: 22.4082
# Epoch 12/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 721.0409 - mean_absolute_error: 17.8693 - val_loss: 1011.1810 - val_mean_absolute_error: 22.2754
# Epoch 13/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 706.7929 - mean_absolute_error: 17.6480 - val_loss: 1048.8517 - val_mean_absolute_error: 21.6145
# Epoch 14/100
# 77760/77760 [==============================] - 2s 19us/sample - loss: 686.9692 - mean_absolute_error: 17.3901 - val_loss: 1101.8087 - val_mean_absolute_error: 22.6235
# Epoch 15/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 685.1229 - mean_absolute_error: 17.3376 - val_loss: 944.5641 - val_mean_absolute_error: 21.6568
# Epoch 16/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 659.9217 - mean_absolute_error: 16.9629 - val_loss: 1016.5472 - val_mean_absolute_error: 22.6201
# Epoch 17/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 659.8840 - mean_absolute_error: 16.9995 - val_loss: 965.5946 - val_mean_absolute_error: 21.0729
# Epoch 18/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 648.8677 - mean_absolute_error: 16.7992 - val_loss: 949.1809 - val_mean_absolute_error: 21.2639
# Epoch 19/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 642.9359 - mean_absolute_error: 16.7676 - val_loss: 1234.3530 - val_mean_absolute_error: 23.6788
# Epoch 20/100
# 77760/77760 [==============================] - 2s 19us/sample - loss: 635.4663 - mean_absolute_error: 16.6185 - val_loss: 1053.6979 - val_mean_absolute_error: 22.6198
# Epoch 21/100
# 77760/77760 [==============================] - 2s 19us/sample - loss: 619.4051 - mean_absolute_error: 16.3888 - val_loss: 965.0122 - val_mean_absolute_error: 20.8223
# Epoch 22/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 619.2895 - mean_absolute_error: 16.3819 - val_loss: 934.7991 - val_mean_absolute_error: 21.5182
# Epoch 23/100
# 77760/77760 [==============================] - 2s 19us/sample - loss: 608.4153 - mean_absolute_error: 16.2108 - val_loss: 1139.4991 - val_mean_absolute_error: 22.7666
# Epoch 24/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 607.9300 - mean_absolute_error: 16.2161 - val_loss: 1090.2224 - val_mean_absolute_error: 22.1574
# Epoch 25/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 608.2704 - mean_absolute_error: 16.2341 - val_loss: 984.7745 - val_mean_absolute_error: 22.0268
# Epoch 26/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 590.6504 - mean_absolute_error: 15.9738 - val_loss: 1016.6723 - val_mean_absolute_error: 21.4232
# Epoch 27/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 587.1691 - mean_absolute_error: 15.9037 - val_loss: 938.7948 - val_mean_absolute_error: 21.6319
# Epoch 28/100
# 77760/77760 [==============================] - 2s 21us/sample - loss: 584.7108 - mean_absolute_error: 15.8326 - val_loss: 844.2435 - val_mean_absolute_error: 20.0859
# Epoch 29/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 586.0828 - mean_absolute_error: 15.8763 - val_loss: 991.5620 - val_mean_absolute_error: 22.2638
# Epoch 30/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 579.5340 - mean_absolute_error: 15.7553 - val_loss: 1039.2742 - val_mean_absolute_error: 22.6970
# Epoch 31/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 575.1307 - mean_absolute_error: 15.7495 - val_loss: 921.1955 - val_mean_absolute_error: 20.8186
# Epoch 32/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 566.1350 - mean_absolute_error: 15.5767 - val_loss: 979.6887 - val_mean_absolute_error: 21.9432
# Epoch 33/100
# 77760/77760 [==============================] - 1s 18us/sample - loss: 568.0845 - mean_absolute_error: 15.5876 - val_loss: 954.9646 - val_mean_absolute_error: 21.5238
# Epoch 34/100
# 77760/77760 [==============================] - 2s 19us/sample - loss: 562.5819 - mean_absolute_error: 15.5328 - val_loss: 1265.3871 - val_mean_absolute_error: 23.5481
# Epoch 35/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 562.1322 - mean_absolute_error: 15.4806 - val_loss: 1003.6554 - val_mean_absolute_error: 21.4807
# Epoch 36/100
# 77760/77760 [==============================] - 1s 18us/sample - loss: 559.2229 - mean_absolute_error: 15.4720 - val_loss: 985.2550 - val_mean_absolute_error: 21.5719
# Epoch 37/100
# 77760/77760 [==============================] - 1s 18us/sample - loss: 553.6806 - mean_absolute_error: 15.3837 - val_loss: 987.8314 - val_mean_absolute_error: 21.3859
# Epoch 38/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 556.6687 - mean_absolute_error: 15.3903 - val_loss: 917.1321 - val_mean_absolute_error: 20.1816
# Epoch 39/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 547.7526 - mean_absolute_error: 15.2620 - val_loss: 980.5204 - val_mean_absolute_error: 21.6587
# Epoch 40/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 556.9417 - mean_absolute_error: 15.3629 - val_loss: 1006.1694 - val_mean_absolute_error: 22.5452
# Epoch 41/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 545.5586 - mean_absolute_error: 15.2034 - val_loss: 876.4800 - val_mean_absolute_error: 20.1360
# Epoch 42/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 538.8181 - mean_absolute_error: 15.1814 - val_loss: 1782.1756 - val_mean_absolute_error: 28.0934
# Epoch 43/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 547.7246 - mean_absolute_error: 15.2334 - val_loss: 1050.7490 - val_mean_absolute_error: 22.5923
# Epoch 44/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 538.6437 - mean_absolute_error: 15.1727 - val_loss: 922.9567 - val_mean_absolute_error: 20.7591
# Epoch 45/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 538.5183 - mean_absolute_error: 15.1200 - val_loss: 995.0966 - val_mean_absolute_error: 20.9529
# Epoch 46/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 535.7783 - mean_absolute_error: 15.0115 - val_loss: 921.6556 - val_mean_absolute_error: 21.1250
# Epoch 47/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 532.1217 - mean_absolute_error: 15.0185 - val_loss: 1026.3208 - val_mean_absolute_error: 20.6433
# Epoch 48/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 533.0292 - mean_absolute_error: 15.0195 - val_loss: 981.0801 - val_mean_absolute_error: 21.7762
# Epoch 49/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 525.8592 - mean_absolute_error: 14.8968 - val_loss: 1193.2110 - val_mean_absolute_error: 23.1956
# Epoch 50/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 525.6065 - mean_absolute_error: 14.9187 - val_loss: 983.9096 - val_mean_absolute_error: 21.5522
# Epoch 51/100
# 77760/77760 [==============================] - 2s 19us/sample - loss: 532.0870 - mean_absolute_error: 14.9436 - val_loss: 977.4559 - val_mean_absolute_error: 21.5379
# Epoch 52/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 523.9293 - mean_absolute_error: 14.8853 - val_loss: 914.0760 - val_mean_absolute_error: 20.5251
# Epoch 53/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 518.6167 - mean_absolute_error: 14.7845 - val_loss: 926.8849 - val_mean_absolute_error: 20.1955
# Epoch 54/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 523.3598 - mean_absolute_error: 14.8582 - val_loss: 953.2501 - val_mean_absolute_error: 20.7466
# Epoch 55/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 518.8548 - mean_absolute_error: 14.7558 - val_loss: 1003.9906 - val_mean_absolute_error: 22.2376
# Epoch 56/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 524.2183 - mean_absolute_error: 14.8452 - val_loss: 1063.2974 - val_mean_absolute_error: 22.9400
# Epoch 57/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 527.7462 - mean_absolute_error: 14.9302 - val_loss: 1163.5440 - val_mean_absolute_error: 24.1293
# Epoch 58/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 515.8280 - mean_absolute_error: 14.7546 - val_loss: 982.9957 - val_mean_absolute_error: 21.0467
# Epoch 59/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 515.5174 - mean_absolute_error: 14.6860 - val_loss: 1121.0526 - val_mean_absolute_error: 22.0627
# Epoch 60/100
# 77760/77760 [==============================] - 2s 19us/sample - loss: 510.4409 - mean_absolute_error: 14.6369 - val_loss: 982.4594 - val_mean_absolute_error: 21.3664
# Epoch 61/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 512.2245 - mean_absolute_error: 14.6445 - val_loss: 919.2628 - val_mean_absolute_error: 20.1192
# Epoch 62/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 515.4078 - mean_absolute_error: 14.7026 - val_loss: 893.4490 - val_mean_absolute_error: 20.1850
# Epoch 63/100
# 77760/77760 [==============================] - 2s 19us/sample - loss: 508.7542 - mean_absolute_error: 14.5645 - val_loss: 978.7771 - val_mean_absolute_error: 20.8807
# Epoch 64/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 511.2956 - mean_absolute_error: 14.6328 - val_loss: 1077.8736 - val_mean_absolute_error: 23.3538
# Epoch 65/100
# 77760/77760 [==============================] - 2s 19us/sample - loss: 509.0051 - mean_absolute_error: 14.5844 - val_loss: 846.9073 - val_mean_absolute_error: 19.2309
# Epoch 66/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 502.4613 - mean_absolute_error: 14.5085 - val_loss: 989.5915 - val_mean_absolute_error: 21.1759
# Epoch 67/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 511.0883 - mean_absolute_error: 14.6376 - val_loss: 905.0520 - val_mean_absolute_error: 20.1126
# Epoch 68/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 501.5398 - mean_absolute_error: 14.4526 - val_loss: 956.0756 - val_mean_absolute_error: 20.3631
# Epoch 69/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 506.5132 - mean_absolute_error: 14.5426 - val_loss: 1024.6471 - val_mean_absolute_error: 22.4543
# Epoch 70/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 512.2677 - mean_absolute_error: 14.5776 - val_loss: 988.2088 - val_mean_absolute_error: 20.7962
# Epoch 71/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 504.1950 - mean_absolute_error: 14.4982 - val_loss: 1070.9662 - val_mean_absolute_error: 21.0535
# Epoch 72/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 492.2281 - mean_absolute_error: 14.3221 - val_loss: 949.3386 - val_mean_absolute_error: 19.8750
# Epoch 73/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 493.6689 - mean_absolute_error: 14.3334 - val_loss: 998.4488 - val_mean_absolute_error: 22.1420
# Epoch 74/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 503.5422 - mean_absolute_error: 14.4924 - val_loss: 1171.9247 - val_mean_absolute_error: 22.8837
# Epoch 75/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 499.6975 - mean_absolute_error: 14.4211 - val_loss: 1389.5832 - val_mean_absolute_error: 27.2808
# Epoch 76/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 495.5882 - mean_absolute_error: 14.3795 - val_loss: 913.2811 - val_mean_absolute_error: 20.1223
# Epoch 77/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 495.9238 - mean_absolute_error: 14.3785 - val_loss: 935.4343 - val_mean_absolute_error: 21.3951
# Epoch 78/100
# 77760/77760 [==============================] - 1s 18us/sample - loss: 501.7428 - mean_absolute_error: 14.4239 - val_loss: 1035.2423 - val_mean_absolute_error: 21.7549
# Epoch 79/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 492.3378 - mean_absolute_error: 14.2792 - val_loss: 910.1357 - val_mean_absolute_error: 20.6371
# Epoch 80/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 496.0762 - mean_absolute_error: 14.3040 - val_loss: 912.1333 - val_mean_absolute_error: 20.9301
# Epoch 81/100
# 77760/77760 [==============================] - 1s 18us/sample - loss: 492.8646 - mean_absolute_error: 14.2831 - val_loss: 1506.2639 - val_mean_absolute_error: 28.2787
# Epoch 82/100
# 77760/77760 [==============================] - 2s 19us/sample - loss: 492.3411 - mean_absolute_error: 14.3064 - val_loss: 1167.6962 - val_mean_absolute_error: 24.7078
# Epoch 83/100
# 77760/77760 [==============================] - 1s 18us/sample - loss: 490.1730 - mean_absolute_error: 14.2438 - val_loss: 966.7984 - val_mean_absolute_error: 21.0812
# Epoch 84/100
# 77760/77760 [==============================] - 1s 18us/sample - loss: 491.6570 - mean_absolute_error: 14.3012 - val_loss: 1025.9518 - val_mean_absolute_error: 21.7665
# Epoch 85/100
# 77760/77760 [==============================] - 1s 18us/sample - loss: 493.1620 - mean_absolute_error: 14.2725 - val_loss: 993.8639 - val_mean_absolute_error: 20.9786
# Epoch 86/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 492.7216 - mean_absolute_error: 14.2707 - val_loss: 900.0604 - val_mean_absolute_error: 19.8126
# Epoch 87/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 494.0944 - mean_absolute_error: 14.3134 - val_loss: 1016.8338 - val_mean_absolute_error: 22.6374
# Epoch 88/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 490.1175 - mean_absolute_error: 14.2148 - val_loss: 1023.9656 - val_mean_absolute_error: 21.8116
# Epoch 89/100
# 77760/77760 [==============================] - 2s 19us/sample - loss: 491.0666 - mean_absolute_error: 14.2899 - val_loss: 868.9458 - val_mean_absolute_error: 19.9495
# Epoch 90/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 484.2808 - mean_absolute_error: 14.1618 - val_loss: 946.1409 - val_mean_absolute_error: 20.9608
# Epoch 91/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 475.3042 - mean_absolute_error: 14.0497 - val_loss: 1025.1510 - val_mean_absolute_error: 21.3771
# Epoch 92/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 482.1782 - mean_absolute_error: 14.1202 - val_loss: 991.8203 - val_mean_absolute_error: 21.7243
# Epoch 93/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 493.2647 - mean_absolute_error: 14.3057 - val_loss: 877.8208 - val_mean_absolute_error: 19.8304
# Epoch 94/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 485.7834 - mean_absolute_error: 14.1152 - val_loss: 973.3330 - val_mean_absolute_error: 20.8065
# Epoch 95/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 482.4420 - mean_absolute_error: 14.1326 - val_loss: 949.4495 - val_mean_absolute_error: 21.3676
# Epoch 96/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 491.0510 - mean_absolute_error: 14.2202 - val_loss: 921.6634 - val_mean_absolute_error: 20.2131
# Epoch 97/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 487.2155 - mean_absolute_error: 14.1879 - val_loss: 936.1536 - val_mean_absolute_error: 20.3371
# Epoch 98/100
# 77760/77760 [==============================] - 1s 18us/sample - loss: 480.1297 - mean_absolute_error: 14.0412 - val_loss: 905.3805 - val_mean_absolute_error: 19.9438
# Epoch 99/100
# 77760/77760 [==============================] - 2s 20us/sample - loss: 479.7882 - mean_absolute_error: 14.0391 - val_loss: 883.9065 - val_mean_absolute_error: 20.0266
# Epoch 100/100
# 77760/77760 [==============================] - 1s 19us/sample - loss: 484.0309 - mean_absolute_error: 14.0645 - val_loss: 1211.1888 - val_mean_absolute_error: 24.3451

# %%
plt.plot(hist.history['mean_absolute_error'])
plt.plot(hist.history['val_mean_absolute_error'])

# %%
y_pred = model.predict(X_test).reshape(-1)
print("[MLP] mae: {:.2f} | mape: {:.2f}% | mspe: {:.2f}%".format(
    mae(y_pred, y_test),
    100 * mape(y_pred,y_test), 100 * mspe(y_pred, y_test)))
# Out:
# [MLP] mae: 29.44 | mape: 21.90% | mspe: 6.42%

# %%
plt.figure(figsize=(8,7))
plt.scatter(y_pred,y_test,c='',marker='^',edgecolors='k')
plt.plot(np.arange(420),np.arange(420),'r:')
plt.xlim([0,420])
plt.ylim([0,420])
# Out:
# (0, 420)

# %% [markdown]
# # Domain Adaptation

# %% [markdown]
# ## Feature-level

# %% [markdown]
# ### SVD -> distribution shift

# %%
X_train, X_test, y_train, y_test = dataset_split(X_nn, Y, split_mode='transfer')
X_ = pd.concat((X_train, X_test), axis=0)

train_idx = range(0,X_train.shape[0])
test_idx = range(X_train.shape[0],X_.shape[0])

# %%
svd = TruncatedSVD(n_components=100, n_iter=20, random_state=1430)
svd.fit(X_.T)
X_new = svd.components_.T
print("[Stats] Var. explanation ratio: {:.4f}".format(svd.explained_variance_ratio_.sum()))
# Out:
# [Stats] Var. explanation ratio: 0.9999

# %% [markdown]
# ### autoencoder -> distribution shift

# %%
def build_ae(input_shape, output_shape, latent_dim, name):
    x_in = Input(shape=(input_shape,),name='input')

    hour = Input(shape=(1,),name='hour')
    weekday = Input(shape=(1,),name='weekday')
    holiday = Input(shape=(1,),name='holiday')
    peak = Input(shape=(1,),name='peak')
    interval = Input(shape=(1,),name='interval')

    v_hour = Flatten()(Embedding(input_dim=24, output_dim=5)(hour))
    v_weekday = Flatten()(Embedding(input_dim=7, output_dim=5)(weekday))
    v_holiday = Flatten()(Embedding(input_dim=2, output_dim=5)(holiday))
    v_peak = Flatten()(Embedding(input_dim=4, output_dim=5)(peak))
    v_interval = Flatten()(Embedding(input_dim=144, output_dim=5)(interval))
    v = Concatenate()([x_in,v_hour,v_weekday,v_holiday,v_peak,v_interval])

    def build_dense(h, units, drop=True, norm=True):
        h = Dense(units=units,use_bias=True,activation=None,
                  kernel_initializer=he_normal(),
                  bias_initializer=constant(0.1),
                  kernel_regularizer=l2())(h)
        if norm:
            h = BatchNormalization()(h)
        h = LeakyReLU(0.1)(h)
        if drop:
            h = Dropout(rate=0.1)(h)
        return h

    h = build_dense(v, 128, norm=False)
    h = build_dense(h, 256, norm=False)
    h = build_dense(h, latent_dim, norm=False)
    #h = build_dense(h, 256, norm=False)
    o = build_dense(h, output_shape, norm=False)

    model = Model(inputs=[x_in,hour,weekday,
                          holiday,peak,interval], outputs=o, name=name)
    
    return model

# %%
X_train, X_test, y_train, y_test = dataset_split(X, Y, split_mode='transfer')

# %%
ae = build_ae(input_shape=X_train[numeric_features].shape[1],
              output_shape=X_train.shape[1],
              latent_dim=512,
              name='autoencoder')
ae.compile(loss='mse',optimizer=Adam(1e-4),metrics=['mae'])

X_ = pd.concat((X_train, X_test),axis=0)

ae_hist = ae.fit([X_[numeric_features],X_['hour'],
                  X['weekday'],X_['holiday'],
                  X_['peak'],X_['interval']],
                 X_,
                 batch_size=512,epochs=500,shuffle=True)
# Out:
# Epoch 1/500
# 103680/103680 [==============================] - 2s 19us/sample - loss: 86.2655 - mean_absolute_error: 3.2398
# Epoch 2/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 60.2201 - mean_absolute_error: 2.3810
# Epoch 3/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 51.1933 - mean_absolute_error: 2.0051
# Epoch 4/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 42.3980 - mean_absolute_error: 1.7169
# Epoch 5/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 36.8759 - mean_absolute_error: 1.5056
# Epoch 6/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 33.9699 - mean_absolute_error: 1.3707
# Epoch 7/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 32.1177 - mean_absolute_error: 1.2797
# Epoch 8/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 30.4581 - mean_absolute_error: 1.2114
# Epoch 9/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 29.2097 - mean_absolute_error: 1.1584
# Epoch 10/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 28.2528 - mean_absolute_error: 1.1152
# Epoch 11/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 27.3522 - mean_absolute_error: 1.0801
# Epoch 12/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 26.6277 - mean_absolute_error: 1.0492
# Epoch 13/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 26.1027 - mean_absolute_error: 1.0252
# Epoch 14/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 25.3772 - mean_absolute_error: 1.0035
# Epoch 15/500
# 103680/103680 [==============================] - 2s 14us/sample - loss: 24.8726 - mean_absolute_error: 0.9857
# Epoch 16/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 23.9993 - mean_absolute_error: 0.9680
# Epoch 17/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 23.9690 - mean_absolute_error: 0.9594
# Epoch 18/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 23.3755 - mean_absolute_error: 0.9468
# Epoch 19/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 22.7111 - mean_absolute_error: 0.9359
# Epoch 20/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 22.3026 - mean_absolute_error: 0.9278
# Epoch 21/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 22.1730 - mean_absolute_error: 0.9216
# Epoch 22/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 21.7180 - mean_absolute_error: 0.9136
# Epoch 23/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 21.3153 - mean_absolute_error: 0.9077
# Epoch 24/500
# 103680/103680 [==============================] - 2s 14us/sample - loss: 21.2224 - mean_absolute_error: 0.9040
# Epoch 25/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 20.5667 - mean_absolute_error: 0.8976
# Epoch 26/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 20.7274 - mean_absolute_error: 0.8967
# Epoch 27/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 20.2244 - mean_absolute_error: 0.8902
# Epoch 28/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 20.2968 - mean_absolute_error: 0.8894
# Epoch 29/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 19.8579 - mean_absolute_error: 0.8848
# Epoch 30/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 19.8358 - mean_absolute_error: 0.8839
# Epoch 31/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 19.7564 - mean_absolute_error: 0.8820
# Epoch 32/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 19.1592 - mean_absolute_error: 0.8768
# Epoch 33/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 19.6222 - mean_absolute_error: 0.8803
# Epoch 34/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 19.2354 - mean_absolute_error: 0.8761
# Epoch 35/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 19.1720 - mean_absolute_error: 0.8731
# Epoch 36/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 19.2876 - mean_absolute_error: 0.8763
# Epoch 37/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.8377 - mean_absolute_error: 0.8717
# Epoch 38/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.6527 - mean_absolute_error: 0.8681
# Epoch 39/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.7215 - mean_absolute_error: 0.8694
# Epoch 40/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.7052 - mean_absolute_error: 0.8688
# Epoch 41/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 18.5714 - mean_absolute_error: 0.8670
# Epoch 42/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 18.4637 - mean_absolute_error: 0.8659
# Epoch 43/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 18.6330 - mean_absolute_error: 0.8673
# Epoch 44/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.5773 - mean_absolute_error: 0.8659
# Epoch 45/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.2717 - mean_absolute_error: 0.8633
# Epoch 46/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 18.6071 - mean_absolute_error: 0.8665
# Epoch 47/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 18.3740 - mean_absolute_error: 0.8630
# Epoch 48/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.3164 - mean_absolute_error: 0.8620
# Epoch 49/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 18.1202 - mean_absolute_error: 0.8587
# Epoch 50/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.2923 - mean_absolute_error: 0.8598
# Epoch 51/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.1908 - mean_absolute_error: 0.8592
# Epoch 52/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.1559 - mean_absolute_error: 0.8599
# Epoch 53/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.2258 - mean_absolute_error: 0.8599
# Epoch 54/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 18.0686 - mean_absolute_error: 0.8571
# Epoch 55/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.1134 - mean_absolute_error: 0.8581
# Epoch 56/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.2868 - mean_absolute_error: 0.8579
# Epoch 57/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.9622 - mean_absolute_error: 0.8565
# Epoch 58/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.1165 - mean_absolute_error: 0.8578
# Epoch 59/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.9233 - mean_absolute_error: 0.8552
# Epoch 60/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.8616 - mean_absolute_error: 0.8544
# Epoch 61/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 18.0397 - mean_absolute_error: 0.8549
# Epoch 62/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.9326 - mean_absolute_error: 0.8531
# Epoch 63/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.9652 - mean_absolute_error: 0.8547
# Epoch 64/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 18.0186 - mean_absolute_error: 0.8556
# Epoch 65/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.8450 - mean_absolute_error: 0.8535
# Epoch 66/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.7205 - mean_absolute_error: 0.8504
# Epoch 67/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.8259 - mean_absolute_error: 0.8543
# Epoch 68/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.8007 - mean_absolute_error: 0.8525
# Epoch 69/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.5900 - mean_absolute_error: 0.8492
# Epoch 70/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.8190 - mean_absolute_error: 0.8506
# Epoch 71/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.9888 - mean_absolute_error: 0.8533
# Epoch 72/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.5050 - mean_absolute_error: 0.8501
# Epoch 73/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.6258 - mean_absolute_error: 0.8509
# Epoch 74/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.9940 - mean_absolute_error: 0.8541s - loss: 18.0895 - mean_absolute_err
# Epoch 75/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.6656 - mean_absolute_error: 0.8516
# Epoch 76/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.6322 - mean_absolute_error: 0.8515
# Epoch 77/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.8974 - mean_absolute_error: 0.8539
# Epoch 78/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.5493 - mean_absolute_error: 0.8510
# Epoch 79/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.8020 - mean_absolute_error: 0.8523
# Epoch 80/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.4273 - mean_absolute_error: 0.8490
# Epoch 81/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.8057 - mean_absolute_error: 0.8515
# Epoch 82/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.5478 - mean_absolute_error: 0.8494
# Epoch 83/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.9007 - mean_absolute_error: 0.8532
# Epoch 84/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.8602 - mean_absolute_error: 0.8525
# Epoch 85/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.7204 - mean_absolute_error: 0.8513
# Epoch 86/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.7175 - mean_absolute_error: 0.8505
# Epoch 87/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.4131 - mean_absolute_error: 0.8485
# Epoch 88/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.4432 - mean_absolute_error: 0.8483
# Epoch 89/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.5818 - mean_absolute_error: 0.8495
# Epoch 90/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.4499 - mean_absolute_error: 0.8485
# Epoch 91/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.6053 - mean_absolute_error: 0.8507
# Epoch 92/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.6964 - mean_absolute_error: 0.8498
# Epoch 93/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.8080 - mean_absolute_error: 0.8514
# Epoch 94/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.3938 - mean_absolute_error: 0.8487
# Epoch 95/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.6620 - mean_absolute_error: 0.8499
# Epoch 96/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.7958 - mean_absolute_error: 0.8531
# Epoch 97/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.6808 - mean_absolute_error: 0.8501
# Epoch 98/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.3626 - mean_absolute_error: 0.8468
# Epoch 99/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.4331 - mean_absolute_error: 0.8476
# Epoch 100/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2774 - mean_absolute_error: 0.8467
# Epoch 101/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2119 - mean_absolute_error: 0.8464
# Epoch 102/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.4502 - mean_absolute_error: 0.8471
# Epoch 103/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.1302 - mean_absolute_error: 0.8460
# Epoch 104/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2981 - mean_absolute_error: 0.8459
# Epoch 105/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.7416 - mean_absolute_error: 0.8501
# Epoch 106/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.8157 - mean_absolute_error: 0.8515
# Epoch 107/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.6643 - mean_absolute_error: 0.8499
# Epoch 108/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.4936 - mean_absolute_error: 0.8474
# Epoch 109/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.6865 - mean_absolute_error: 0.8498
# Epoch 110/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.6146 - mean_absolute_error: 0.8485
# Epoch 111/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.6654 - mean_absolute_error: 0.8492
# Epoch 112/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3798 - mean_absolute_error: 0.8471
# Epoch 113/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.8541 - mean_absolute_error: 0.8507
# Epoch 114/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.8103 - mean_absolute_error: 0.8492
# Epoch 115/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.5335 - mean_absolute_error: 0.8473
# Epoch 116/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2634 - mean_absolute_error: 0.8457
# Epoch 117/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2115 - mean_absolute_error: 0.8460
# Epoch 118/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.3005 - mean_absolute_error: 0.8460
# Epoch 119/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.3566 - mean_absolute_error: 0.8450
# Epoch 120/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.5892 - mean_absolute_error: 0.8482
# Epoch 121/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0677 - mean_absolute_error: 0.8439
# Epoch 122/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.3704 - mean_absolute_error: 0.8449
# Epoch 123/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3018 - mean_absolute_error: 0.8462
# Epoch 124/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.5679 - mean_absolute_error: 0.8483
# Epoch 125/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2227 - mean_absolute_error: 0.8453
# Epoch 126/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3047 - mean_absolute_error: 0.8450
# Epoch 127/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0514 - mean_absolute_error: 0.8421
# Epoch 128/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2237 - mean_absolute_error: 0.8449
# Epoch 129/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3907 - mean_absolute_error: 0.8445
# Epoch 130/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.4047 - mean_absolute_error: 0.8449
# Epoch 131/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.4354 - mean_absolute_error: 0.8453
# Epoch 132/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2612 - mean_absolute_error: 0.8438
# Epoch 133/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9479 - mean_absolute_error: 0.8410
# Epoch 134/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2889 - mean_absolute_error: 0.8415
# Epoch 135/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9362 - mean_absolute_error: 0.8410
# Epoch 136/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.6367 - mean_absolute_error: 0.8455
# Epoch 137/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.0792 - mean_absolute_error: 0.8416
# Epoch 138/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.3236 - mean_absolute_error: 0.8431
# Epoch 139/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.5484 - mean_absolute_error: 0.8449
# Epoch 140/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8896 - mean_absolute_error: 0.8387
# Epoch 141/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.3891 - mean_absolute_error: 0.8438
# Epoch 142/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.4403 - mean_absolute_error: 0.8438
# Epoch 143/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.4571 - mean_absolute_error: 0.8436
# Epoch 144/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1689 - mean_absolute_error: 0.8413
# Epoch 145/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0101 - mean_absolute_error: 0.8382
# Epoch 146/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9732 - mean_absolute_error: 0.8393
# Epoch 147/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9824 - mean_absolute_error: 0.8379
# Epoch 148/500
# 103680/103680 [==============================] - 2s 14us/sample - loss: 17.2416 - mean_absolute_error: 0.8394
# Epoch 149/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0412 - mean_absolute_error: 0.8383
# Epoch 150/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0533 - mean_absolute_error: 0.8380
# Epoch 151/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.6123 - mean_absolute_error: 0.8428
# Epoch 152/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2463 - mean_absolute_error: 0.8400
# Epoch 153/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2383 - mean_absolute_error: 0.8391
# Epoch 154/500
# 103680/103680 [==============================] - ETA: 0s - loss: 17.2407 - mean_absolute_error: 0.83 - 2s 15us/sample - loss: 17.2390 - mean_absolute_error: 0.8385
# Epoch 155/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1125 - mean_absolute_error: 0.8392
# Epoch 156/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.5267 - mean_absolute_error: 0.8403
# Epoch 157/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1724 - mean_absolute_error: 0.8380
# Epoch 158/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.6645 - mean_absolute_error: 0.8429
# Epoch 159/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.5195 - mean_absolute_error: 0.8413
# Epoch 160/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9888 - mean_absolute_error: 0.8358
# Epoch 161/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0426 - mean_absolute_error: 0.8376
# Epoch 162/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3460 - mean_absolute_error: 0.8387
# Epoch 163/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3566 - mean_absolute_error: 0.8404
# Epoch 164/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2644 - mean_absolute_error: 0.8371s
# Epoch 165/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.4459 - mean_absolute_error: 0.8381
# Epoch 166/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0435 - mean_absolute_error: 0.8360
# Epoch 167/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3058 - mean_absolute_error: 0.8379
# Epoch 168/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.1784 - mean_absolute_error: 0.8373
# Epoch 169/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2736 - mean_absolute_error: 0.8367
# Epoch 170/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1262 - mean_absolute_error: 0.8348
# Epoch 171/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3262 - mean_absolute_error: 0.8380
# Epoch 172/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3755 - mean_absolute_error: 0.8373
# Epoch 173/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1189 - mean_absolute_error: 0.8359
# Epoch 174/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3112 - mean_absolute_error: 0.8358
# Epoch 175/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3819 - mean_absolute_error: 0.8368
# Epoch 176/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9666 - mean_absolute_error: 0.8328
# Epoch 177/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0745 - mean_absolute_error: 0.8349
# Epoch 178/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2150 - mean_absolute_error: 0.8350
# Epoch 179/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1482 - mean_absolute_error: 0.8369
# Epoch 180/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.5018 - mean_absolute_error: 0.8376
# Epoch 181/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1695 - mean_absolute_error: 0.8344
# Epoch 182/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2057 - mean_absolute_error: 0.8359
# Epoch 183/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2844 - mean_absolute_error: 0.8359
# Epoch 184/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0904 - mean_absolute_error: 0.8329
# Epoch 185/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.5989 - mean_absolute_error: 0.8392
# Epoch 186/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.3485 - mean_absolute_error: 0.8373
# Epoch 187/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.1493 - mean_absolute_error: 0.8347
# Epoch 188/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.3908 - mean_absolute_error: 0.8369
# Epoch 189/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2164 - mean_absolute_error: 0.8351
# Epoch 190/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0598 - mean_absolute_error: 0.8342
# Epoch 191/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.4889 - mean_absolute_error: 0.8372
# Epoch 192/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.4411 - mean_absolute_error: 0.8373
# Epoch 193/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.5242 - mean_absolute_error: 0.8382
# Epoch 194/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8196 - mean_absolute_error: 0.8315
# Epoch 195/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0584 - mean_absolute_error: 0.8330
# Epoch 196/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3919 - mean_absolute_error: 0.8358
# Epoch 197/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0695 - mean_absolute_error: 0.8347
# Epoch 198/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8718 - mean_absolute_error: 0.8316
# Epoch 199/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1914 - mean_absolute_error: 0.8340
# Epoch 200/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3151 - mean_absolute_error: 0.8349
# Epoch 201/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1298 - mean_absolute_error: 0.8351
# Epoch 202/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.1845 - mean_absolute_error: 0.8335
# Epoch 203/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1735 - mean_absolute_error: 0.8330
# Epoch 204/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1635 - mean_absolute_error: 0.8348
# Epoch 205/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3855 - mean_absolute_error: 0.8363
# Epoch 206/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9192 - mean_absolute_error: 0.8317
# Epoch 207/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1844 - mean_absolute_error: 0.8351
# Epoch 208/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1096 - mean_absolute_error: 0.8335
# Epoch 209/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0059 - mean_absolute_error: 0.8315
# Epoch 210/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1923 - mean_absolute_error: 0.8348
# Epoch 211/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2619 - mean_absolute_error: 0.8353
# Epoch 212/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0490 - mean_absolute_error: 0.8321
# Epoch 213/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9996 - mean_absolute_error: 0.8326
# Epoch 214/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9919 - mean_absolute_error: 0.8320
# Epoch 215/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0104 - mean_absolute_error: 0.8322
# Epoch 216/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1230 - mean_absolute_error: 0.8317
# Epoch 217/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2120 - mean_absolute_error: 0.8349
# Epoch 218/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1919 - mean_absolute_error: 0.8335
# Epoch 219/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3958 - mean_absolute_error: 0.8349
# Epoch 220/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1403 - mean_absolute_error: 0.8331
# Epoch 221/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0976 - mean_absolute_error: 0.8319
# Epoch 222/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8380 - mean_absolute_error: 0.8308
# Epoch 223/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0501 - mean_absolute_error: 0.8319
# Epoch 224/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9192 - mean_absolute_error: 0.8309
# Epoch 225/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0544 - mean_absolute_error: 0.8311
# Epoch 226/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.0307 - mean_absolute_error: 0.8316
# Epoch 227/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1559 - mean_absolute_error: 0.8318
# Epoch 228/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0591 - mean_absolute_error: 0.8322
# Epoch 229/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8725 - mean_absolute_error: 0.8293
# Epoch 230/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1405 - mean_absolute_error: 0.8306
# Epoch 231/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0725 - mean_absolute_error: 0.8303
# Epoch 232/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3219 - mean_absolute_error: 0.8325
# Epoch 233/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.4062 - mean_absolute_error: 0.8343
# Epoch 234/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2872 - mean_absolute_error: 0.8328
# Epoch 235/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.3080 - mean_absolute_error: 0.8316
# Epoch 236/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0347 - mean_absolute_error: 0.8306
# Epoch 237/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1843 - mean_absolute_error: 0.8315
# Epoch 238/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9490 - mean_absolute_error: 0.8288
# Epoch 239/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1920 - mean_absolute_error: 0.8320
# Epoch 240/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9347 - mean_absolute_error: 0.8295
# Epoch 241/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8972 - mean_absolute_error: 0.8290
# Epoch 242/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1175 - mean_absolute_error: 0.8299
# Epoch 243/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8353 - mean_absolute_error: 0.8280
# Epoch 244/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0927 - mean_absolute_error: 0.8313
# Epoch 245/500
# 103680/103680 [==============================] - 2s 14us/sample - loss: 17.0632 - mean_absolute_error: 0.8304
# Epoch 246/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9632 - mean_absolute_error: 0.8290
# Epoch 247/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2326 - mean_absolute_error: 0.8318
# Epoch 248/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0174 - mean_absolute_error: 0.8301
# Epoch 249/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2575 - mean_absolute_error: 0.8317
# Epoch 250/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9349 - mean_absolute_error: 0.8282
# Epoch 251/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0182 - mean_absolute_error: 0.8291
# Epoch 252/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9258 - mean_absolute_error: 0.8274
# Epoch 253/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2939 - mean_absolute_error: 0.8304
# Epoch 254/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.1600 - mean_absolute_error: 0.8307
# Epoch 255/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0913 - mean_absolute_error: 0.8297
# Epoch 256/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0569 - mean_absolute_error: 0.8296
# Epoch 257/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.3357 - mean_absolute_error: 0.8312
# Epoch 258/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2078 - mean_absolute_error: 0.8295
# Epoch 259/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.4925 - mean_absolute_error: 0.8232
# Epoch 260/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.3014 - mean_absolute_error: 0.8302
# Epoch 261/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8598 - mean_absolute_error: 0.8277
# Epoch 262/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9868 - mean_absolute_error: 0.8278
# Epoch 263/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0362 - mean_absolute_error: 0.8309
# Epoch 264/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0550 - mean_absolute_error: 0.8285
# Epoch 265/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0547 - mean_absolute_error: 0.8284
# Epoch 266/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9599 - mean_absolute_error: 0.8293
# Epoch 267/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0299 - mean_absolute_error: 0.8284
# Epoch 268/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1778 - mean_absolute_error: 0.8293
# Epoch 269/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.1113 - mean_absolute_error: 0.8287
# Epoch 270/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9449 - mean_absolute_error: 0.8270
# Epoch 271/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9498 - mean_absolute_error: 0.8261
# Epoch 272/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0932 - mean_absolute_error: 0.8280
# Epoch 273/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7989 - mean_absolute_error: 0.8268
# Epoch 274/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0571 - mean_absolute_error: 0.8273
# Epoch 275/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0706 - mean_absolute_error: 0.8278
# Epoch 276/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7943 - mean_absolute_error: 0.8262
# Epoch 277/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7962 - mean_absolute_error: 0.8254
# Epoch 278/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9648 - mean_absolute_error: 0.8272
# Epoch 279/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2086 - mean_absolute_error: 0.8284
# Epoch 280/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2629 - mean_absolute_error: 0.8299
# Epoch 281/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9672 - mean_absolute_error: 0.8279
# Epoch 282/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9794 - mean_absolute_error: 0.8266
# Epoch 283/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2446 - mean_absolute_error: 0.8281
# Epoch 284/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0580 - mean_absolute_error: 0.8269
# Epoch 285/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9746 - mean_absolute_error: 0.8263
# Epoch 286/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1491 - mean_absolute_error: 0.8291
# Epoch 287/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2242 - mean_absolute_error: 0.8299
# Epoch 288/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1315 - mean_absolute_error: 0.8271
# Epoch 289/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2077 - mean_absolute_error: 0.8290
# Epoch 290/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0290 - mean_absolute_error: 0.8276
# Epoch 291/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7780 - mean_absolute_error: 0.8251
# Epoch 292/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0110 - mean_absolute_error: 0.8275
# Epoch 293/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8208 - mean_absolute_error: 0.8251
# Epoch 294/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9677 - mean_absolute_error: 0.8257
# Epoch 295/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7841 - mean_absolute_error: 0.8240
# Epoch 296/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0807 - mean_absolute_error: 0.8272
# Epoch 297/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9217 - mean_absolute_error: 0.8254
# Epoch 298/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2157 - mean_absolute_error: 0.8292
# Epoch 299/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8440 - mean_absolute_error: 0.8252
# Epoch 300/500
# 103680/103680 [==============================] - 2s 14us/sample - loss: 16.8042 - mean_absolute_error: 0.8243
# Epoch 301/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9665 - mean_absolute_error: 0.8255
# Epoch 302/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0263 - mean_absolute_error: 0.8254
# Epoch 303/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9267 - mean_absolute_error: 0.8251
# Epoch 304/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.3186 - mean_absolute_error: 0.8286s - loss: 17.4187
# Epoch 305/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1020 - mean_absolute_error: 0.8278
# Epoch 306/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2045 - mean_absolute_error: 0.8273
# Epoch 307/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8911 - mean_absolute_error: 0.8245
# Epoch 308/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9724 - mean_absolute_error: 0.8246
# Epoch 309/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0455 - mean_absolute_error: 0.8246
# Epoch 310/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0970 - mean_absolute_error: 0.8271
# Epoch 311/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.7502 - mean_absolute_error: 0.8248
# Epoch 312/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9707 - mean_absolute_error: 0.8244
# Epoch 313/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0213 - mean_absolute_error: 0.8250
# Epoch 314/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.1006 - mean_absolute_error: 0.8262
# Epoch 315/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1884 - mean_absolute_error: 0.8264
# Epoch 316/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1504 - mean_absolute_error: 0.8264
# Epoch 317/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0712 - mean_absolute_error: 0.8271
# Epoch 318/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9854 - mean_absolute_error: 0.8245
# Epoch 319/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8816 - mean_absolute_error: 0.8242
# Epoch 320/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9341 - mean_absolute_error: 0.8240
# Epoch 321/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7364 - mean_absolute_error: 0.8222
# Epoch 322/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0618 - mean_absolute_error: 0.8255
# Epoch 323/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7215 - mean_absolute_error: 0.8224
# Epoch 324/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0614 - mean_absolute_error: 0.8240
# Epoch 325/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9811 - mean_absolute_error: 0.8229
# Epoch 326/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7414 - mean_absolute_error: 0.8233
# Epoch 327/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0387 - mean_absolute_error: 0.8239
# Epoch 328/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9204 - mean_absolute_error: 0.8249
# Epoch 329/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 16.9013 - mean_absolute_error: 0.8218
# Epoch 330/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9472 - mean_absolute_error: 0.8240
# Epoch 331/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8917 - mean_absolute_error: 0.8226
# Epoch 332/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8114 - mean_absolute_error: 0.8235
# Epoch 333/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9978 - mean_absolute_error: 0.8260
# Epoch 334/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9301 - mean_absolute_error: 0.8230
# Epoch 335/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1071 - mean_absolute_error: 0.8245
# Epoch 336/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.6940 - mean_absolute_error: 0.8224
# Epoch 337/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9732 - mean_absolute_error: 0.8240
# Epoch 338/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9157 - mean_absolute_error: 0.8245
# Epoch 339/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8557 - mean_absolute_error: 0.8232
# Epoch 340/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8818 - mean_absolute_error: 0.8240
# Epoch 341/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.1164 - mean_absolute_error: 0.8243
# Epoch 342/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.6847 - mean_absolute_error: 0.8223
# Epoch 343/500
# 103680/103680 [==============================] - ETA: 0s - loss: 17.0600 - mean_absolute_error: 0.82 - 1s 14us/sample - loss: 17.0345 - mean_absolute_error: 0.8256
# Epoch 344/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0432 - mean_absolute_error: 0.8244
# Epoch 345/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0368 - mean_absolute_error: 0.8233
# Epoch 346/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9027 - mean_absolute_error: 0.8232
# Epoch 347/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8943 - mean_absolute_error: 0.8234
# Epoch 348/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9657 - mean_absolute_error: 0.8227
# Epoch 349/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0792 - mean_absolute_error: 0.8227
# Epoch 350/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8961 - mean_absolute_error: 0.8224
# Epoch 351/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0402 - mean_absolute_error: 0.8232
# Epoch 352/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.6547 - mean_absolute_error: 0.8223
# Epoch 353/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9601 - mean_absolute_error: 0.8238
# Epoch 354/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0663 - mean_absolute_error: 0.8230
# Epoch 355/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0804 - mean_absolute_error: 0.8230
# Epoch 356/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8901 - mean_absolute_error: 0.8221
# Epoch 357/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0888 - mean_absolute_error: 0.8244
# Epoch 358/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.1349 - mean_absolute_error: 0.8253
# Epoch 359/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0278 - mean_absolute_error: 0.8239
# Epoch 360/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0327 - mean_absolute_error: 0.8235
# Epoch 361/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9200 - mean_absolute_error: 0.8235
# Epoch 362/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.0540 - mean_absolute_error: 0.8251
# Epoch 363/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9425 - mean_absolute_error: 0.8226
# Epoch 364/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8791 - mean_absolute_error: 0.8232
# Epoch 365/500
# 103680/103680 [==============================] - 2s 14us/sample - loss: 17.1365 - mean_absolute_error: 0.8230
# Epoch 366/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8749 - mean_absolute_error: 0.8222
# Epoch 367/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1738 - mean_absolute_error: 0.8230
# Epoch 368/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9698 - mean_absolute_error: 0.8224
# Epoch 369/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9111 - mean_absolute_error: 0.8221
# Epoch 370/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0087 - mean_absolute_error: 0.8226
# Epoch 371/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8650 - mean_absolute_error: 0.8224
# Epoch 372/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.6943 - mean_absolute_error: 0.8214
# Epoch 373/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8637 - mean_absolute_error: 0.8214
# Epoch 374/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2125 - mean_absolute_error: 0.8235
# Epoch 375/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9474 - mean_absolute_error: 0.8228
# Epoch 376/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8120 - mean_absolute_error: 0.8211
# Epoch 377/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9187 - mean_absolute_error: 0.8226
# Epoch 378/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2020 - mean_absolute_error: 0.8237
# Epoch 379/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1109 - mean_absolute_error: 0.8234
# Epoch 380/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.6507 - mean_absolute_error: 0.8206
# Epoch 381/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7147 - mean_absolute_error: 0.8205
# Epoch 382/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9727 - mean_absolute_error: 0.8226
# Epoch 383/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9761 - mean_absolute_error: 0.8232
# Epoch 384/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9336 - mean_absolute_error: 0.8221
# Epoch 385/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8835 - mean_absolute_error: 0.8219
# Epoch 386/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1656 - mean_absolute_error: 0.8254
# Epoch 387/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8813 - mean_absolute_error: 0.8198
# Epoch 388/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8394 - mean_absolute_error: 0.8211
# Epoch 389/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0211 - mean_absolute_error: 0.8233
# Epoch 390/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9092 - mean_absolute_error: 0.8224
# Epoch 391/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8565 - mean_absolute_error: 0.8223
# Epoch 392/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0651 - mean_absolute_error: 0.8231
# Epoch 393/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9226 - mean_absolute_error: 0.8240
# Epoch 394/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0449 - mean_absolute_error: 0.8240
# Epoch 395/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8842 - mean_absolute_error: 0.8215
# Epoch 396/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.6819 - mean_absolute_error: 0.8193
# Epoch 397/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1652 - mean_absolute_error: 0.8233
# Epoch 398/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9898 - mean_absolute_error: 0.8207
# Epoch 399/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9846 - mean_absolute_error: 0.8228
# Epoch 400/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9219 - mean_absolute_error: 0.8205
# Epoch 401/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0573 - mean_absolute_error: 0.8219
# Epoch 402/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 16.9353 - mean_absolute_error: 0.8212
# Epoch 403/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8485 - mean_absolute_error: 0.8217
# Epoch 404/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.6275 - mean_absolute_error: 0.8189
# Epoch 405/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2073 - mean_absolute_error: 0.8241
# Epoch 406/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8296 - mean_absolute_error: 0.8198
# Epoch 407/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8340 - mean_absolute_error: 0.8215
# Epoch 408/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9614 - mean_absolute_error: 0.8223
# Epoch 409/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9844 - mean_absolute_error: 0.8209
# Epoch 410/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 16.8037 - mean_absolute_error: 0.8189
# Epoch 411/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9598 - mean_absolute_error: 0.8195
# Epoch 412/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9365 - mean_absolute_error: 0.8212
# Epoch 413/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.6958 - mean_absolute_error: 0.8200
# Epoch 414/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2858 - mean_absolute_error: 0.8228
# Epoch 415/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9607 - mean_absolute_error: 0.8218
# Epoch 416/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2770 - mean_absolute_error: 0.8255
# Epoch 417/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1536 - mean_absolute_error: 0.8232
# Epoch 418/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9738 - mean_absolute_error: 0.8224
# Epoch 419/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0949 - mean_absolute_error: 0.8225
# Epoch 420/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0653 - mean_absolute_error: 0.8217
# Epoch 421/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.1089 - mean_absolute_error: 0.8223
# Epoch 422/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.7070 - mean_absolute_error: 0.8185
# Epoch 423/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8184 - mean_absolute_error: 0.8205
# Epoch 424/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.7537 - mean_absolute_error: 0.8202
# Epoch 425/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.2054 - mean_absolute_error: 0.8236
# Epoch 426/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2545 - mean_absolute_error: 0.8236
# Epoch 427/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1016 - mean_absolute_error: 0.8209
# Epoch 428/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8071 - mean_absolute_error: 0.8196
# Epoch 429/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0444 - mean_absolute_error: 0.8231
# Epoch 430/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0653 - mean_absolute_error: 0.8223
# Epoch 431/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 16.9396 - mean_absolute_error: 0.8214
# Epoch 432/500
# 103680/103680 [==============================] - 2s 17us/sample - loss: 16.9881 - mean_absolute_error: 0.8204s - loss: 16.98
# Epoch 433/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9122 - mean_absolute_error: 0.8206
# Epoch 434/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.7251 - mean_absolute_error: 0.8180
# Epoch 435/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8957 - mean_absolute_error: 0.8201
# Epoch 436/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9785 - mean_absolute_error: 0.8207
# Epoch 437/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.7246 - mean_absolute_error: 0.8171
# Epoch 438/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.1239 - mean_absolute_error: 0.8221
# Epoch 439/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 16.9398 - mean_absolute_error: 0.8212
# Epoch 440/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 16.6565 - mean_absolute_error: 0.8188
# Epoch 441/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 16.7844 - mean_absolute_error: 0.8199
# Epoch 442/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0104 - mean_absolute_error: 0.8215
# Epoch 443/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.0008 - mean_absolute_error: 0.8208
# Epoch 444/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.1389 - mean_absolute_error: 0.8235
# Epoch 445/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.7037 - mean_absolute_error: 0.8191
# Epoch 446/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.7478 - mean_absolute_error: 0.8188
# Epoch 447/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.0702 - mean_absolute_error: 0.8224
# Epoch 448/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 17.0901 - mean_absolute_error: 0.8223
# Epoch 449/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9630 - mean_absolute_error: 0.8207
# Epoch 450/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 16.7834 - mean_absolute_error: 0.8179
# Epoch 451/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 16.8690 - mean_absolute_error: 0.8219
# Epoch 452/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8922 - mean_absolute_error: 0.8203
# Epoch 453/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.7909 - mean_absolute_error: 0.8182
# Epoch 454/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0124 - mean_absolute_error: 0.8215
# Epoch 455/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9568 - mean_absolute_error: 0.8198
# Epoch 456/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9379 - mean_absolute_error: 0.8205
# Epoch 457/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8177 - mean_absolute_error: 0.8184
# Epoch 458/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9821 - mean_absolute_error: 0.8219
# Epoch 459/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9035 - mean_absolute_error: 0.8216
# Epoch 460/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.7958 - mean_absolute_error: 0.8180
# Epoch 461/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9920 - mean_absolute_error: 0.8196
# Epoch 462/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9584 - mean_absolute_error: 0.8197
# Epoch 463/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9254 - mean_absolute_error: 0.8209
# Epoch 464/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8582 - mean_absolute_error: 0.8201
# Epoch 465/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8591 - mean_absolute_error: 0.8175
# Epoch 466/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1067 - mean_absolute_error: 0.8216
# Epoch 467/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0449 - mean_absolute_error: 0.8204
# Epoch 468/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8865 - mean_absolute_error: 0.8195
# Epoch 469/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7515 - mean_absolute_error: 0.8185
# Epoch 470/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.5963 - mean_absolute_error: 0.8163
# Epoch 471/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8768 - mean_absolute_error: 0.8189
# Epoch 472/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.1996 - mean_absolute_error: 0.8229
# Epoch 473/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7463 - mean_absolute_error: 0.8180
# Epoch 474/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.0352 - mean_absolute_error: 0.8198
# Epoch 475/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9985 - mean_absolute_error: 0.8210
# Epoch 476/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 17.2574 - mean_absolute_error: 0.8224
# Epoch 477/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9960 - mean_absolute_error: 0.8203
# Epoch 478/500
# 103680/103680 [==============================] - 2s 16us/sample - loss: 16.8749 - mean_absolute_error: 0.8196
# Epoch 479/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8376 - mean_absolute_error: 0.8181
# Epoch 480/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8872 - mean_absolute_error: 0.8185
# Epoch 481/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7881 - mean_absolute_error: 0.8187
# Epoch 482/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.7674 - mean_absolute_error: 0.8182
# Epoch 483/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9714 - mean_absolute_error: 0.8205
# Epoch 484/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.7096 - mean_absolute_error: 0.8174
# Epoch 485/500
# 103680/103680 [==============================] - 2s 14us/sample - loss: 16.5764 - mean_absolute_error: 0.8157
# Epoch 486/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.9075 - mean_absolute_error: 0.8182
# Epoch 487/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9897 - mean_absolute_error: 0.8192
# Epoch 488/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0905 - mean_absolute_error: 0.8197
# Epoch 489/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9817 - mean_absolute_error: 0.8206
# Epoch 490/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9077 - mean_absolute_error: 0.8184
# Epoch 491/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.0326 - mean_absolute_error: 0.8191
# Epoch 492/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.7074 - mean_absolute_error: 0.8168
# Epoch 493/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8481 - mean_absolute_error: 0.8181
# Epoch 494/500
# 103680/103680 [==============================] - 2s 14us/sample - loss: 17.0750 - mean_absolute_error: 0.8210
# Epoch 495/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 17.1342 - mean_absolute_error: 0.8207
# Epoch 496/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.8827 - mean_absolute_error: 0.8181
# Epoch 497/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.9681 - mean_absolute_error: 0.8200
# Epoch 498/500
# 103680/103680 [==============================] - 2s 15us/sample - loss: 16.6817 - mean_absolute_error: 0.8171
# Epoch 499/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.8440 - mean_absolute_error: 0.8182
# Epoch 500/500
# 103680/103680 [==============================] - 1s 14us/sample - loss: 16.6826 - mean_absolute_error: 0.8156

# %%
embedder = Model(inputs=ae.input, outputs=ae.layers[23].output)
X_new = embedder.predict([X_[numeric_features], X_['hour'],
                          X['weekday'], X_['holiday'],
                          X_['peak'], X_['interval']])

# %% [markdown]
# ### kNN-regressor

# %%
knn = KNeighborsRegressor(n_neighbors=10,weights='distance',n_jobs=-1)
knn = knn.fit(X_new[train_idx],y_train)

# %%
y_pred = knn.predict(X_new[test_idx])
print("[kNN] mae: {:.2f} | mape: {:.2f}% | mspe: {:.2f}%".format(
    mae(y_pred, y_test),
    100 * mape(y_pred,y_test), 100 * mspe(y_pred, y_test)))
# Out:
# [kNN] mae: 56.95 | mape: 51.23% | mspe: 28.67%

# %% [markdown]
# ### GBM-regressor

# %%
train_data = lgb.Dataset(X_new[train_idx], y_train)

params = {
    'objective':'regression',
    'boosting':'gbdt',
    'num_rounds':10000,
    'learning_rate':0.01,
    'max_depth':8,
    'num_leaves':80,
    'bagging_fraction':0.8,
    'bagging_freq':50,
    'verbose':2
}

# %%
gbm = lgb.train(params, train_data)

# %%
y_pred = gbm.predict(X_new[train_idx])

print("[LightGBM] mae: {:.2f} | mape: {:.2f}% | mspe: {:.2f}%".format(
    mae(y_pred, y_train),
    100 * mape(y_pred,y_train), 100 * mspe(y_pred, y_train)))

y_pred = gbm.predict(X_new[test_idx])

print("[LightGBM] mae: {:.2f} | mape: {:.2f}% | mspe: {:.2f}%".format(
    mae(y_pred, y_test),
    100 * mape(y_pred,y_test), 100 * mspe(y_pred, y_test)))
# Out:
# [LightGBM] mae: 18.67 | mape: 22.40% | mspe: 5.41%
# [LightGBM] mae: 62.86 | mape: 56.55% | mspe: 33.41%

# %%
plt.figure(figsize=(8,7))
plt.scatter(y_pred,y_test,c='',marker='^',edgecolors='k')
plt.plot(np.arange(420),np.arange(420),'r:')
plt.xlim([0,420])
plt.ylim([0,420])
# Out:
# (0, 420)

# %% [markdown]
# ### NN-regressor

# %%
def build_nn_regressor(input_shape, drop_rate, name):
    x_in = Input(shape=(input_shape,),name='input')
    
    def build_dense(h, units, drop=True, norm=True):
        h = Dense(units=units,use_bias=True,activation=None,
                  kernel_initializer=he_normal(),
                  bias_initializer=constant(0.1),
                  kernel_regularizer=l2())(h)
        if norm:
            h = BatchNormalization()(h)
        h = LeakyReLU(0.1)(h)
        if drop:
            h = Dropout(rate=drop_rate)(h)
        return h
    
    h = build_dense(x_in, 512)
    h = build_dense(h, 256)
    h = build_dense(h, 128)
    h = build_dense(h, 64, drop=False)
    h = build_dense(h, 32, drop=False, norm=False)
    h = build_dense(h, 1, drop=False, norm=False)
    
    model = Model(inputs=x_in, outputs=h, name=name)
    
    return model

# %%
model = build_nn_regressor(X_new.shape[1],drop_rate=0.5, name='mlp-regressor')
model.compile(loss='mse',optimizer=Adam(3e-4), metrics=['mae'])
model.summary()
# Out:
# Model: "mlp-regressor"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 512)]             0
# _________________________________________________________________
# dense_110 (Dense)            (None, 512)               262656
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 512)               2048
# _________________________________________________________________
# leaky_re_lu_110 (LeakyReLU)  (None, 512)               0
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_111 (Dense)            (None, 256)               131328
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 256)               1024
# _________________________________________________________________
# leaky_re_lu_111 (LeakyReLU)  (None, 256)               0
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_112 (Dense)            (None, 128)               32896
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_112 (LeakyReLU)  (None, 128)               0
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_113 (Dense)            (None, 64)                8256
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_113 (LeakyReLU)  (None, 64)                0
# _________________________________________________________________
# dense_114 (Dense)            (None, 32)                2080
# _________________________________________________________________
# leaky_re_lu_114 (LeakyReLU)  (None, 32)                0
# _________________________________________________________________
# dense_115 (Dense)            (None, 1)                 33
# _________________________________________________________________
# leaky_re_lu_115 (LeakyReLU)  (None, 1)                 0
# =================================================================
# Total params: 441,089
# Trainable params: 439,169
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
hist = model.fit(X_new[train_idx], y_train,
                 batch_size=256, epochs=200,
                 shuffle=True,
                 validation_data=[X_new[test_idx],y_test])

# %%
y_pred = model.predict(X_new[test_idx]).reshape(-1)

print("[MLP] mae: {:.2f} | mape: {:.2f}% | mspe: {:.2f}%".format(
    mae(y_pred, y_test),
    100 * mape(y_pred,y_test), 100 * mspe(y_pred, y_test)))
# Out:
# [MLP] mae: 29.92 | mape: 26.92% | mspe: 8.40%
